# %% [markdown]
# ### Week 11 – Natural Language Processing (NLP Basics)

# %% [markdown]
# #### Imports

# %%
import pandas as pd
import numpy as np
import nltk
import re

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# #### Download Required NLTK Resources

# %%
import nltk

nltk.download('punkt', quiet=True)
nltk.download('punkt_tab', quiet=True)
nltk.download('stopwords', quiet=True)
# Out:
# True

# %% [markdown]
# #### Create Sample Text Dataset
#
# (For Assignment 11 – text preprocessing)

# %%
data = {
    'text': [
        "This project uses AI for house price prediction",
        "Machine learning and deep learning are powerful tools",
        "Natural Language Processing is used for text analysis",
        "Tokenization and TF IDF are basic NLP steps"
    ]
}

df = pd.DataFrame(data)
df
# Out:
#                                                 text
# 0    This project uses AI for house price prediction
# 1  Machine learning and deep learning are powerfu...
# 2  Natural Language Processing is used for text a...
# 3        Tokenization and TF IDF are basic NLP steps

# %% [markdown]
# #### Text Cleaning
#
# (lowercase + remove symbols)

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    return text

df['clean_text'] = df['text'].apply(clean_text)
df
# Out:
#                                                 text  \
# 0    This project uses AI for house price prediction
# 1  Machine learning and deep learning are powerfu...
# 2  Natural Language Processing is used for text a...
# 3        Tokenization and TF IDF are basic NLP steps
#
#                                           clean_text
# 0    this project uses ai for house price prediction
# 1  machine learning and deep learning are powerfu...
# 2  natural language processing is used for text a...
# 3        tokenization and tf idf are basic nlp steps

# %% [markdown]
# #### Tokenization
#
# (Splitting sentences into words)

# %%
df['tokens'] = df['clean_text'].apply(word_tokenize)
df
# Out:
#                                                 text  \
# 0    This project uses AI for house price prediction
# 1  Machine learning and deep learning are powerfu...
# 2  Natural Language Processing is used for text a...
# 3        Tokenization and TF IDF are basic NLP steps
#
#                                           clean_text  \
# 0    this project uses ai for house price prediction
# 1  machine learning and deep learning are powerfu...
# 2  natural language processing is used for text a...
# 3        tokenization and tf idf are basic nlp steps
#
#                                               tokens
# 0  [this, project, uses, ai, for, house, price, p...
# 1  [machine, learning, and, deep, learning, are, ...
# 2  [natural, language, processing, is, used, for,...
# 3  [tokenization, and, tf, idf, are, basic, nlp, ...

# %% [markdown]
# #### Stopword Removal
#
# (Removing words like: is, the, and, for)

# %%
stop_words = set(stopwords.words('english'))

df['tokens_no_stopwords'] = df['tokens'].apply(
    lambda words: [w for w in words if w not in stop_words]
)

df
# Out:
#                                                 text  \
# 0    This project uses AI for house price prediction
# 1  Machine learning and deep learning are powerfu...
# 2  Natural Language Processing is used for text a...
# 3        Tokenization and TF IDF are basic NLP steps
#
#                                           clean_text  \
# 0    this project uses ai for house price prediction
# 1  machine learning and deep learning are powerfu...
# 2  natural language processing is used for text a...
# 3        tokenization and tf idf are basic nlp steps
#
#                                               tokens  \
# 0  [this, project, uses, ai, for, house, price, p...
# 1  [machine, learning, and, deep, learning, are, ...
# 2  [natural, language, processing, is, used, for,...
# 3  [tokenization, and, tf, idf, are, basic, nlp, ...
#
#                                  tokens_no_stopwords
# 0      [project, uses, ai, house, price, prediction]
# 1  [machine, learning, deep, learning, powerful, ...
# 2  [natural, language, processing, used, text, an...
# 3         [tokenization, tf, idf, basic, nlp, steps]

# %% [markdown]
# #### Join Tokens Back to Text
#
# (Required for TF-IDF)

# %%
df['final_text'] = df['tokens_no_stopwords'].apply(lambda x: ' '.join(x))
df
# Out:
#                                                 text  \
# 0    This project uses AI for house price prediction
# 1  Machine learning and deep learning are powerfu...
# 2  Natural Language Processing is used for text a...
# 3        Tokenization and TF IDF are basic NLP steps
#
#                                           clean_text  \
# 0    this project uses ai for house price prediction
# 1  machine learning and deep learning are powerfu...
# 2  natural language processing is used for text a...
# 3        tokenization and tf idf are basic nlp steps
#
#                                               tokens  \
# 0  [this, project, uses, ai, for, house, price, p...
# 1  [machine, learning, and, deep, learning, are, ...
# 2  [natural, language, processing, is, used, for,...
# 3  [tokenization, and, tf, idf, are, basic, nlp, ...
#
#                                  tokens_no_stopwords  \
# 0      [project, uses, ai, house, price, prediction]
# 1  [machine, learning, deep, learning, powerful, ...
# 2  [natural, language, processing, used, text, an...
# 3         [tokenization, tf, idf, basic, nlp, steps]
#
#                                        final_text
# 0          project uses ai house price prediction
# 1   machine learning deep learning powerful tools
# 2  natural language processing used text analysis
# 3             tokenization tf idf basic nlp steps

# %% [markdown]
# #### TF-IDF Vectorization
#
# (Convert text into numerical features)

# %%
vectorizer = TfidfVectorizer()
X_tfidf = vectorizer.fit_transform(df['final_text'])

print("TF-IDF Shape:", X_tfidf.shape)
# Out:
# TF-IDF Shape: (4, 23)

# %% [markdown]
# #### View TF-IDF Feature Matrix

# %%
tfidf_df = pd.DataFrame(
    X_tfidf.toarray(),
    columns=vectorizer.get_feature_names_out()
)

tfidf_df
# Out:
#          ai  analysis     basic      deep     house       idf  language  \
# 0  0.408248  0.000000  0.000000  0.000000  0.408248  0.000000  0.000000
# 1  0.000000  0.000000  0.000000  0.353553  0.000000  0.000000  0.000000
# 2  0.000000  0.408248  0.000000  0.000000  0.000000  0.000000  0.408248
# 3  0.000000  0.000000  0.408248  0.000000  0.000000  0.408248  0.000000
#
#    learning   machine   natural  ...     price  processing   project  \
# 0  0.000000  0.000000  0.000000  ...  0.408248    0.000000  0.408248
# 1  0.707107  0.353553  0.000000  ...  0.000000    0.000000  0.000000
# 2  0.000000  0.000000  0.408248  ...  0.000000    0.408248  0.000000
# 3  0.000000  0.000000  0.000000  ...  0.000000    0.000000  0.000000
#
#       steps      text        tf  tokenization     tools      used      uses
# 0  0.000000  0.000000  0.000000      0.000000  0.000000  0.000000  0.408248
# 1  0.000000  0.000000  0.000000      0.000000  0.353553  0.000000  0.000000
# 2  0.000000  0.408248  0.000000      0.000000  0.000000  0.408248  0.000000
# 3  0.408248  0.000000  0.408248      0.408248  0.000000  0.000000  0.000000
#
# [4 rows x 23 columns]

# %% [markdown]
# #### Simple Verification Test

# %%
word_tokenize("NLP is working fine")
# Out:
# ['NLP', 'is', 'working', 'fine']
